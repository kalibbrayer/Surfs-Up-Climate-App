# %%
import pandas as pd 
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Float, Integer, String
from sqlalchemy.ext.declarative import declarative_base
import matplotlib.pyplot as plt
% matplotlib inline
Base = automap_base()

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# Use the Inspector to explore the database and print the table names
### BEGIN SOLUTION
inspector = inspect(engine)
inspector.get_table_names()
### END SOLUTION
# Out:
# ['Measurements', 'Stations']

# %%
# Use Inspector to print the column names and types
### BEGIN SOLUTION
columns = inspector.get_columns('Measurements')
for c in columns:
    print(c['name'], c["type"])
### END SOLUTION
# Out:
# id INTEGER
# station VARCHAR
# date VARCHAR
# prcp FLOAT
# tobs INTEGER

# %%
# Use Inspector to print the column names and types
### BEGIN SOLUTION
columns = inspector.get_columns('Stations')
for c in columns:
    print(c['name'], c["type"])
### END SOLUTION
# Out:
# id INTEGER
# station VARCHAR
# name VARCHAR
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Use `engine.execute` to select and display the rows from the Measurements table
### BEGIN SOLUTION
engine.execute('SELECT * FROM Measurements').fetchall()
### END SOLUTION
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76),
#  (5, 'USC00519397', '2010-01-07', 0.06, 70),
#  (6, 'USC00519397', '2010-01-08', 0.0, 64),
#  (7, 'USC00519397', '2010-01-09', 0.0, 68),
#  (8, 'USC00519397', '2010-01-10', 0.0, 73),
#  (9, 'USC00519397', '2010-01-11', 0.01, 64),
#  (10, 'USC00519397', '2010-01-12', 0.0, 61),
#  (11, 'USC00519397', '2010-01-14', 0.0, 66),
#  (12, 'USC00519397', '2010-01-15', 0.0, 65),
#  (13, 'USC00519397', '2010-01-16', 0.0, 68),
#  (14, 'USC00519397', '2010-01-17', 0.0, 64),
#  (15, 'USC00519397', '2010-01-18', 0.0, 72),
#  (16, 'USC00519397', '2010-01-19', 0.0, 66),
#  (17, 'USC00519397', '2010-01-20', 0.0, 66),
#  (18, 'USC00519397', '2010-01-21', 0.0, 69),
#  (19, 'USC00519397', '2010-01-22', 0.0, 67),
#  (20, 'USC00519397', '2010-01-23', 0.0, 67),
#  (21, 'USC00519397', '2010-01-24', 0.01, 71),
#  (22, 'USC00519397', '2010-01-25', 0.0, 67),
#  (23, 'USC00519397', '2010-01-26', 0.04, 76),
#  (24, 'USC00519397', '2010-01-27', 0.12, 68),
#  (25, 'USC00519397', '2010-01-28', 0.0, 72),
#  (26, 'USC00519397', '2010-01-31', 0.03, 67),
#  (27, 'USC00519397', '2010-02-01', 0.01, 66),
#  (28, 'USC00519397', '2010-02-04', 0.01, 69),
#  (29, 'USC00519397', '2010-02-05', 0.0, 67),
#  (30, 'USC00519397', '2010-02-06', 0.0, 67),
#  (31, 'USC00519397', '2010-02-07', 0.0, 64),
#  (32, 'USC00519397', '2010-02-08', 0.0, 69),
#  (33, 'USC00519397', '2010-02-09', 0.0, 73),
#  (34, 'USC00519397', '2010-02-11', 0.0, 73),
#  (35, 'USC00519397', '2010-02-12', 0.02, 69),
#  (36, 'USC00519397', '2010-02-13', 0.01, 69),
#  (37, 'USC00519397', '2010-02-14', 0.0, 69),
#  (38, 'USC00519397', '2010-02-15', 0.0, 71),
#  (39, 'USC00519397', '2010-02-16', 0.0, 61),
#  (40, 'USC00519397', '2010-02-17', 0.0, 69),
#  (41, 'USC00519397', '2010-02-20', 0.03, 64),
#  (42, 'USC00519397', '2010-02-21', 0.0, 65),
#  (43, 'USC00519397', '2010-02-22', 0.0, 67),
#  (44, 'USC00519397', '2010-02-23', 0.0, 68),
#  (45, 'USC00519397', '2010-02-24', 0.0, 65),
#  (46, 'USC00519397', '2010-02-25', 0.0, 76),
#  (47, 'USC00519397', '2010-02-26', 0.0, 75),
#  (48, 'USC00519397', '2010-02-28', 0.0, 66),
#  (49, 'USC00519397', '2010-03-01', 0.01, 70),
#  (50, 'USC00519397', '2010-03-02', 0.0, 72),
#  (51, 'USC00519397', '2010-03-03', 0.0, 73),
#  (52, 'USC00519397', '2010-03-04', 0.12, 70),
#  (53, 'USC00519397', '2010-03-05', 0.08, 71),
#  (54, 'USC00519397', '2010-03-06', 0.03, 72),
#  (55, 'USC00519397', '2010-03-07', 0.0, 72),
#  (56, 'USC00519397', '2010-03-08', 0.43, 69),
#  (57, 'USC00519397', '2010-03-09', 0.06, 70),
#  (58, 'USC00519397', '2010-03-12', 0.0, 72),
#  (59, 'USC00519397', '2010-03-13', 0.0, 73),
#  (60, 'USC00519397', '2010-03-14', 0.0, 70),
#  (61, 'USC00519397', '2010-03-15', 0.06, 71),
#  (62, 'USC00519397', '2010-03-17', 0.0, 68),
#  (63, 'USC00519397', '2010-03-18', 0.0, 70),
#  (64, 'USC00519397', '2010-03-21', 0.0, 72),
#  (65, 'USC00519397', '2010-03-22', 0.0, 69),
#  (66, 'USC00519397', '2010-03-23', 0.0, 68),
#  (67, 'USC00519397', '2010-03-24', 0.0, 74),
#  (68, 'USC00519397', '2010-03-27', 0.0, 72),
#  (69, 'USC00519397', '2010-03-28', 0.0, 73),
#  (70, 'USC00519397', '2010-03-29', 0.0, 74),
#  (71, 'USC00519397', '2010-03-30', 0.0, 73),
#  (72, 'USC00519397', '2010-03-31', 0.0, 73),
#  (73, 'USC00519397', '2010-04-01', 0.0, 74),
#  (74, 'USC00519397', '2010-04-02', 0.01, 74),
#  (75, 'USC00519397', '2010-04-03', 0.17, 74),
#  (76, 'USC00519397', '2010-04-04', 0.15, 71),
#  (77, 'USC00519397', '2010-04-05', 0.27, 72),
#  (78, 'USC00519397', '2010-04-06', 0.01, 75),
#  (79, 'USC00519397', '2010-04-08', 0.0, 75),
#  (80, 'USC00519397', '2010-04-09', 0.01, 75),
#  (81, 'USC00519397', '2010-04-10', 0.0, 75),
#  (82, 'USC00519397', '2010-04-11', 0.01, 73),
#  (83, 'USC00519397', '2010-04-12', 0.01, 73),
#  (84, 'USC00519397', '2010-04-13', 0.0, 71),
#  (85, 'USC00519397', '2010-04-15', 0.0, 71),
#  (86, 'USC00519397', '2010-04-16', 0.01, 68),
#  (87, 'USC00519397', '2010-04-17', 0.0, 70),
#  (88, 'USC00519397', '2010-04-18', 0.0, 71),
#  (89, 'USC00519397', '2010-04-19', 0.0, 74),
#  (90, 'USC00519397', '2010-04-20', 0.04, 71),
#  (91, 'USC00519397', '2010-04-21', 0.01, 75),
#  (92, 'USC00519397', '2010-04-22', 0.0, 76),
#  (93, 'USC00519397', '2010-04-23', 0.02, 75),
#  (94, 'USC00519397', '2010-04-24', 0.0, 75),
#  (95, 'USC00519397', '2010-04-25', 0.0, 76),
#  (96, 'USC00519397', '2010-04-26', 0.0, 76),
#  (97, 'USC00519397', '2010-04-28', 0.0, 76),
#  (98, 'USC00519397', '2010-04-30', 0.0, 77),
#  (99, 'USC00519397', '2010-05-01', 0.0, 77),
#  (100, 'USC00519397', '2010-05-02', 0.03, 73),
#  (101, 'USC00519397', '2010-05-03', 0.2, 74),
#  (102, 'USC00519397', '2010-05-04', 0.08, 76),
#  (103, 'USC00519397', '2010-05-05', 0.01, 76),
#  (104, 'USC00519397', '2010-05-06', 0.0, 80),
#  (105, 'USC00519397', '2010-05-07', 0.05, 74),
#  (106, 'USC00519397', '2010-05-08', 0.0, 77),
#  (107, 'USC00519397', '2010-05-09', 0.0, 77),
#  (108, 'USC00519397', '2010-05-10', 0.0, 76),
#  (109, 'USC00519397', '2010-05-11', 0.0, 77),
#  (110, 'USC00519397', '2010-05-13', 0.0, 78),
#  (111, 'USC00519397', '2010-05-14', 0.0, 78),
#  (112, 'USC00519397', '2010-05-15', 0.0, 75),
#  (113, 'USC00519397', '2010-05-16', 0.03, 73),
#  (114, 'USC00519397', '2010-05-17', 0.0, 77),
#  (115, 'USC00519397', '2010-05-18', 0.0, 76),
#  (116, 'USC00519397', '2010-05-19', 0.0, 77),
#  (117, 'USC00519397', '2010-05-22', 0.0, 78),
#  (118, 'USC00519397', '2010-05-23', 0.05, 75),
#  (119, 'USC00519397', '2010-05-24', 0.0, 77),
#  (120, 'USC00519397', '2010-05-25', 0.0, 77),
#  (121, 'USC00519397', '2010-05-26', 0.02, 77),
#  (122, 'USC00519397', '2010-05-27', 0.0, 76),
#  (123, 'USC00519397', '2010-05-28', 0.0, 75),
#  (124, 'USC00519397', '2010-05-29', 0.0, 77),
#  (125, 'USC00519397', '2010-05-30', 0.0, 77),
#  (126, 'USC00519397', '2010-05-31', 0.0, 77),
#  (127, 'USC00519397', '2010-06-01', 0.0, 78),
#  (128, 'USC00519397', '2010-06-02', 0.01, 76),
#  (129, 'USC00519397', '2010-06-03', 0.0, 78),
#  (130, 'USC00519397', '2010-06-04', 0.0, 76),
#  (131, 'USC00519397', '2010-06-05', 0.0, 77),
#  (132, 'USC00519397', '2010-06-06', 0.0, 78),
#  (133, 'USC00519397', '2010-06-07', 0.0, 77),
#  (134, 'USC00519397', '2010-06-08', 0.0, 78),
#  (135, 'USC00519397', '2010-06-09', 0.0, 78),
#  (136, 'USC00519397', '2010-06-10', 0.0, 79),
#  (137, 'USC00519397', '2010-06-11', 0.0, 78),
#  (138, 'USC00519397', '2010-06-12', 0.0, 78),
#  (139, 'USC00519397', '2010-06-13', 0.0, 78),
#  (140, 'USC00519397', '2010-06-14', 0.0, 77),
#  (141, 'USC00519397', '2010-06-15', 0.0, 78),
#  (142, 'USC00519397', '2010-06-16', 0.0, 78),
#  (143, 'USC00519397', '2010-06-17', 0.0, 77),
#  (144, 'USC00519397', '2010-06-18', 0.0, 77),
#  (145, 'USC00519397', '2010-06-19', 0.0, 82),
#  (146, 'USC00519397', '2010-06-20', 0.0, 78),
#  (147, 'USC00519397', '2010-06-21', 0.0, 78),
#  (148, 'USC00519397', '2010-06-22', 0.0, 78),
#  (149, 'USC00519397', '2010-06-23', 0.0, 78),
#  (150, 'USC00519397', '2010-06-24', 0.0, 78),
#  (151, 'USC00519397', '2010-06-25', 0.0, 77),
#  (152, 'USC00519397', '2010-06-26', 0.02, 76),
#  (153, 'USC00519397', '2010-06-27', 0.0, 78),
#  (154, 'USC00519397', '2010-06-28', 0.0, 78),
#  (155, 'USC00519397', '2010-06-29', 0.0, 78),
#  (156, 'USC00519397', '2010-06-30', 0.0, 78),
#  (157, 'USC00519397', '2010-07-01', 0.01, 75),
#  (158, 'USC00519397', '2010-07-02', 0.05, 77),
#  (159, 'USC00519397', '2010-07-03', 0.09, 77),
#  (160, 'USC00519397', '2010-07-04', 0.05, 78),
#  (161, 'USC00519397', '2010-07-05', 0.06, 78),
#  (162, 'USC00519397', '2010-07-06', 0.08, 76),
#  (163, 'USC00519397', '2010-07-07', 0.08, 74),
#  (164, 'USC00519397', '2010-07-08', 0.03, 76),
#  (165, 'USC00519397', '2010-07-09', 0.06, 74),
#  (166, 'USC00519397', '2010-07-10', 0.09, 76),
#  (167, 'USC00519397', '2010-07-11', 0.0, 78),
#  (168, 'USC00519397', '2010-07-12', 0.0, 77),
#  (169, 'USC00519397', '2010-07-13', 0.0, 80),
#  (170, 'USC00519397', '2010-07-17', 0.02, 76),
#  (171, 'USC00519397', '2010-07-18', 0.0, 77),
#  (172, 'USC00519397', '2010-07-19', 0.04, 77),
#  (173, 'USC00519397', '2010-07-21', 0.0, 80),
#  (174, 'USC00519397', '2010-07-22', 0.0, 78),
#  (175, 'USC00519397', '2010-07-24', 0.0, 80),
#  (176, 'USC00519397', '2010-07-25', 0.0, 79),
#  (177, 'USC00519397', '2010-07-26', 0.0, 78),
#  (178, 'USC00519397', '2010-07-27', 0.0, 79),
#  (179, 'USC00519397', '2010-07-28', 0.0, 78),
#  (180, 'USC00519397', '2010-07-29', 0.0, 79),
#  (181, 'USC00519397', '2010-07-30', 0.0, 78),
#  (182, 'USC00519397', '2010-07-31', 0.02, 77),
#  (183, 'USC00519397', '2010-08-01', 0.04, 77),
#  (184, 'USC00519397', '2010-08-02', 0.01, 76),
#  (185, 'USC00519397', '2010-08-03', 0.02, 77),
#  (186, 'USC00519397', '2010-08-04', 0.07, 77),
#  (187, 'USC00519397', '2010-08-05', 0.08, 75),
#  (188, 'USC00519397', '2010-08-06', 0.03, 75),
#  (189, 'USC00519397', '2010-08-07', 0.0, 80),
#  (190, 'USC00519397', '2010-08-08', 0.0, 77),
#  (191, 'USC00519397', '2010-08-09', 0.0, 78),
#  (192, 'USC00519397', '2010-08-10', 0.0, 78),
#  (193, 'USC00519397', '2010-08-11', 0.0, 77),
#  (194, 'USC00519397', '2010-08-12', 0.0, 76),
#  (195, 'USC00519397', '2010-08-13', 0.0, 78),
#  (196, 'USC00519397', '2010-08-14', 0.0, 78),
#  (197, 'USC00519397', '2010-08-15', 0.01, 76),
#  (198, 'USC00519397', '2010-08-16', 0.0, 76),
#  (199, 'USC00519397', '2010-08-17', 0.05, 74),
#  (200, 'USC00519397', '2010-08-18', 0.0, 77),
#  (201, 'USC00519397', '2010-08-19', 0.0, 79),
#  (202, 'USC00519397', '2010-08-20', 0.0, 79),
#  (203, 'USC00519397', '2010-08-21', 0.0, 79),
#  (204, 'USC00519397', '2010-08-22', 0.0, 75),
#  (205, 'USC00519397', '2010-08-23', 0.01, 87),
#  (206, 'USC00519397', '2010-08-24', 0.0, 78),
#  (207, 'USC00519397', '2010-08-25', 0.04, 76),
#  (208, 'USC00519397', '2010-08-26', 0.03, 78),
#  (209, 'USC00519397', '2010-08-27', 0.0, 78),
#  (210, 'USC00519397', '2010-08-28', 0.04, 79),
#  (211, 'USC00519397', '2010-08-29', 0.0, 78),
#  (212, 'USC00519397', '2010-08-30', 0.0, 78),
#  (213, 'USC00519397', '2010-08-31', 0.0, 80),
#  (214, 'USC00519397', '2010-09-01', 0.0, 77),
#  (215, 'USC00519397', '2010-09-02', 0.02, 76),
#  (216, 'USC00519397', '2010-09-03', 0.04, 78),
#  (217, 'USC00519397', '2010-09-04', 0.01, 77),
#  (218, 'USC00519397', '2010-09-05', 0.0, 77),
#  (219, 'USC00519397', '2010-09-06', 0.0, 77),
#  (220, 'USC00519397', '2010-09-07', 0.06, 76),
#  (221, 'USC00519397', '2010-09-08', 0.0, 78),
#  (222, 'USC00519397', '2010-09-09', 0.0, 78),
#  (223, 'USC00519397', '2010-09-10', 0.0, 78),
#  (224, 'USC00519397', '2010-09-11', 0.05, 78),
#  (225, 'USC00519397', '2010-09-12', 0.0, 74),
#  (226, 'USC00519397', '2010-09-13', 0.0, 78),
#  (227, 'USC00519397', '2010-09-14', 0.0, 79),
#  (228, 'USC00519397', '2010-09-15', 0.0, 77),
#  (229, 'USC00519397', '2010-09-16', 0.0, 79),
#  (230, 'USC00519397', '2010-09-17', 0.0, 78),
#  (231, 'USC00519397', '2010-09-19', 0.0, 78),
#  (232, 'USC00519397', '2010-09-20', 0.0, 78),
#  (233, 'USC00519397', '2010-09-21', 0.0, 79),
#  (234, 'USC00519397', '2010-09-22', 0.04, 76),
#  (235, 'USC00519397', '2010-09-23', 0.0, 78),
#  (236, 'USC00519397', '2010-09-24', 0.0, 78),
#  (237, 'USC00519397', '2010-09-25', 0.0, 79),
#  (238, 'USC00519397', '2010-09-26', 0.0, 74),
#  (239, 'USC00519397', '2010-09-27', 0.0, 75),
#  (240, 'USC00519397', '2010-09-28', 0.0, 75),
#  (241, 'USC00519397', '2010-09-29', 0.0, 78),
#  (242, 'USC00519397', '2010-09-30', 0.57, 73),
#  (243, 'USC00519397', '2010-10-01', 0.31, 78),
#  (244, 'USC00519397', '2010-10-02', 0.03, 78),
#  (245, 'USC00519397', '2010-10-03', 0.0, 78),
#  (246, 'USC00519397', '2010-10-04', 0.06, 78),
#  (247, 'USC00519397', '2010-10-05', 0.0, 80),
#  (248, 'USC00519397', '2010-10-06', 0.0, 79),
#  (249, 'USC00519397', '2010-10-07', 0.0, 79),
#  (250, 'USC00519397', '2010-10-08', 0.0, 78),
#  (251, 'USC00519397', '2010-10-09', 0.0, 78),
#  (252, 'USC00519397', '2010-10-10', 0.0, 78),
#  (253, 'USC00519397', '2010-10-11', 0.0, 77),
#  (254, 'USC00519397', '2010-10-12', 0.0, 79),
#  (255, 'USC00519397', '2010-10-13', 0.0, 78),
#  (256, 'USC00519397', '2010-10-15', 0.0, 78),
#  (257, 'USC00519397', '2010-10-16', 0.0, 77),
#  (258, 'USC00519397', '2010-10-17', 0.0, 76),
#  (259, 'USC00519397', '2010-10-18', 0.0, 76),
#  (260, 'USC00519397', '2010-10-19', 0.07, 72),
#  (261, 'USC00519397', '2010-10-20', 0.0, 74),
#  (262, 'USC00519397', '2010-10-21', 0.0, 80),
#  (263, 'USC00519397', '2010-10-22', 0.0, 77),
#  (264, 'USC00519397', '2010-10-23', 0.0, 75),
#  (265, 'USC00519397', '2010-10-24', 0.0, 78),
#  (266, 'USC00519397', '2010-10-25', 0.0, 78),
#  (267, 'USC00519397', '2010-10-26', 0.07, 76),
#  (268, 'USC00519397', '2010-10-27', 0.05, 79),
#  (269, 'USC00519397', '2010-10-28', 0.06, 78),
#  (270, 'USC00519397', '2010-10-29', 0.03, 78),
#  (271, 'USC00519397', '2010-10-30', 0.02, 77),
#  (272, 'USC00519397', '2010-10-31', 0.0, 76),
#  (273, 'USC00519397', '2010-11-01', 0.01, 75),
#  (274, 'USC00519397', '2010-11-02', 0.01, 73),
#  (275, 'USC00519397', '2010-11-05', 0.0, 77),
#  (276, 'USC00519397', '2010-11-06', 0.0, 76),
#  (277, 'USC00519397', '2010-11-07', 0.0, 77),
#  (278, 'USC00519397', '2010-11-08', 0.0, 76),
#  (279, 'USC00519397', '2010-11-09', 0.0, 73),
#  (280, 'USC00519397', '2010-11-10', 0.23, 73),
#  (281, 'USC00519397', '2010-11-11', 0.0, 77),
#  (282, 'USC00519397', '2010-11-12', 0.0, 77),
#  (283, 'USC00519397', '2010-11-13', 0.0, 76),
#  (284, 'USC00519397', '2010-11-16', 0.0, 73),
#  (285, 'USC00519397', '2010-11-17', 0.0, 73),
#  (286, 'USC00519397', '2010-11-20', 0.03, 69),
#  (287, 'USC00519397', '2010-11-21', 0.0, 69),
#  (288, 'USC00519397', '2010-11-22', 0.0, 68),
#  (289, 'USC00519397', '2010-11-23', 0.0, 69),
#  (290, 'USC00519397', '2010-11-24', 0.0, 76),
#  (291, 'USC00519397', '2010-11-25', 0.0, 76),
#  (292, 'USC00519397', '2010-11-27', 0.0, 75),
#  (293, 'USC00519397', '2010-11-28', 0.0, 74),
#  (294, 'USC00519397', '2010-11-29', 0.0, 69),
#  (295, 'USC00519397', '2010-11-30', 0.0, 74),
#  (296, 'USC00519397', '2010-12-01', 0.04, 76),
#  (297, 'USC00519397', '2010-12-03', 0.0, 74),
#  (298, 'USC00519397', '2010-12-04', 0.0, 74),
#  (299, 'USC00519397', '2010-12-06', 0.0, 64),
#  (300, 'USC00519397', '2010-12-07', 0.0, 64),
#  (301, 'USC00519397', '2010-12-08', 0.0, 67),
#  (302, 'USC00519397', '2010-12-09', 0.0, 77),
#  (303, 'USC00519397', '2010-12-10', 1.58, 66),
#  (304, 'USC00519397', '2010-12-11', 0.77, 69),
#  (305, 'USC00519397', '2010-12-12', 0.0, 68),
#  (306, 'USC00519397', '2010-12-13', 0.0, 68),
#  (307, 'USC00519397', '2010-12-14', 0.0, 71),
#  (308, 'USC00519397', '2010-12-15', 0.0, 74),
#  (309, 'USC00519397', '2010-12-16', 0.0, 67),
#  (310, 'USC00519397', '2010-12-17', 0.0, 66),
#  (311, 'USC00519397', '2010-12-18', 0.0, 69),
#  (312, 'USC00519397', '2010-12-19', 1.4, 71),
#  (313, 'USC00519397', '2010-12-23', 0.0, 70),
#  (314, 'USC00519397', '2010-12-24', 0.0, 70),
#  (315, 'USC00519397', '2010-12-27', 0.13, 74),
#  (316, 'USC00519397', '2010-12-28', 0.55, 71),
#  (317, 'USC00519397', '2010-12-29', 0.06, 75),
#  (318, 'USC00519397', '2010-12-30', 0.01, 75),
#  (319, 'USC00519397', '2010-12-31', 0.0, 72),
#  (320, 'USC00519397', '2011-01-01', 0.0, 69),
#  (321, 'USC00519397', '2011-01-02', 0.0, 72),
#  (322, 'USC00519397', '2011-01-03', 0.0, 74),
#  (323, 'USC00519397', '2011-01-04', 0.0, 73),
#  (324, 'USC00519397', '2011-01-05', 0.0, 64),
#  (325, 'USC00519397', '2011-01-06', 0.01, 65),
#  (326, 'USC00519397', '2011-01-07', 0.0, 68),
#  (327, 'USC00519397', '2011-01-08', 0.0, 62),
#  (328, 'USC00519397', '2011-01-09', 0.0, 58),
#  (329, 'USC00519397', '2011-01-10', 0.0, 73),
#  (330, 'USC00519397', '2011-01-11', 0.09, 60),
#  (331, 'USC00519397', '2011-01-14', 0.03, 76),
#  (332, 'USC00519397', '2011-01-15', 0.0, 68),
#  (333, 'USC00519397', '2011-01-16', 0.0, 66),
#  (334, 'USC00519397', '2011-01-17', 0.0, 64),
#  (335, 'USC00519397', '2011-01-18', 0.0, 64),
#  (336, 'USC00519397', '2011-01-19', 0.03, 64),
#  (337, 'USC00519397', '2011-01-20', 0.0, 76),
#  (338, 'USC00519397', '2011-01-21', 0.0, 75),
#  (339, 'USC00519397', '2011-01-22', 0.0, 68),
#  (340, 'USC00519397', '2011-01-23', 0.0, 68),
#  (341, 'USC00519397', '2011-01-24', 0.0, 72),
#  (342, 'USC00519397', '2011-01-25', 0.0, 63),
#  (343, 'USC00519397', '2011-01-27', 0.0, 68),
#  (344, 'USC00519397', '2011-01-28', 0.0, 75),
#  (345, 'USC00519397', '2011-01-29', 0.0, 65),
#  (346, 'USC00519397', '2011-01-30', 0.0, 64),
#  (347, 'USC00519397', '2011-01-31', 0.22, 68),
#  (348, 'USC00519397', '2011-02-01', 0.0, 68),
#  (349, 'USC00519397', '2011-02-02', 0.0, 66),
#  (350, 'USC00519397', '2011-02-03', 0.0, 67),
#  (351, 'USC00519397', '2011-02-04', 0.0, 64),
#  (352, 'USC00519397', '2011-02-05', 0.0, 65),
#  (353, 'USC00519397', '2011-02-06', 0.0, 75),
#  (354, 'USC00519397', '2011-02-07', 1.29, 68),
#  (355, 'USC00519397', '2011-02-08', 1.3, 71),
#  (356, 'USC00519397', '2011-02-09', 0.0, 71),
#  (357, 'USC00519397', '2011-02-10', 0.29, 71),
#  (358, 'USC00519397', '2011-02-13', 0.0, 68),
#  (359, 'USC00519397', '2011-02-14', 0.04, 72),
#  (360, 'USC00519397', '2011-02-15', 0.05, 70),
#  (361, 'USC00519397', '2011-02-16', 0.0, 74),
#  (362, 'USC00519397', '2011-02-19', 0.0, 67),
#  (363, 'USC00519397', '2011-02-20', 1.72, 71),
#  (364, 'USC00519397', '2011-02-21', 0.0, 71),
#  (365, 'USC00519397', '2011-02-22', 0.82, 71),
#  (366, 'USC00519397', '2011-02-23', 0.0, 74),
#  (367, 'USC00519397', '2011-02-24', 0.2, 68),
#  (368, 'USC00519397', '2011-02-25', 0.0, 71),
#  (369, 'USC00519397', '2011-02-26', 0.0, 69),
#  (370, 'USC00519397', '2011-02-27', 0.0, 69),
#  (371, 'USC00519397', '2011-02-28', 0.0, 68),
#  (372, 'USC00519397', '2011-03-01', 0.1, 68),
#  (373, 'USC00519397', '2011-03-02', 0.0, 72),
#  (374, 'USC00519397', '2011-03-03', 0.0, 74),
#  (375, 'USC00519397', '2011-03-04', 0.88, 72),
#  (376, 'USC00519397', '2011-03-05', 0.4, 69),
#  (377, 'USC00519397', '2011-03-06', 0.03, 70),
#  (378, 'USC00519397', '2011-03-09', 0.2, 71),
#  (379, 'USC00519397', '2011-03-10', 0.15, 71),
#  (380, 'USC00519397', '2011-03-12', 0.0, 72),
#  (381, 'USC00519397', '2011-03-13', 0.0, 70),
#  (382, 'USC00519397', '2011-03-14', 0.0, 71),
#  (383, 'USC00519397', '2011-03-16', 0.0, 76),
#  (384, 'USC00519397', '2011-03-17', 0.01, 73),
#  (385, 'USC00519397', '2011-03-18', 0.05, 74),
#  (386, 'USC00519397', '2011-03-19', 0.01, 74),
#  (387, 'USC00519397', '2011-03-20', 0.02, 74),
#  (388, 'USC00519397', '2011-03-21', 0.0, 74),
#  (389, 'USC00519397', '2011-03-22', 0.02, 74),
#  (390, 'USC00519397', '2011-03-23', 0.0, 74),
#  (391, 'USC00519397', '2011-03-24', 0.06, 73),
#  (392, 'USC00519397', '2011-03-25', 0.0, 74),
#  (393, 'USC00519397', '2011-03-26', 0.0, 74),
#  (394, 'USC00519397', '2011-03-27', 0.0, 73),
#  (395, 'USC00519397', '2011-03-28', 0.04, 74),
#  (396, 'USC00519397', '2011-03-30', 0.0, 75),
#  (397, 'USC00519397', '2011-03-31', 0.0, 74),
#  (398, 'USC00519397', '2011-04-01', 0.05, 74),
#  (399, 'USC00519397', '2011-04-02', 0.04, 75),
#  (400, 'USC00519397', '2011-04-03', 0.0, 74),
#  (401, 'USC00519397', '2011-04-04', 0.0, 75),
#  (402, 'USC00519397', '2011-04-05', 0.0, 74),
#  (403, 'USC00519397', '2011-04-06', 0.09, 70),
#  (404, 'USC00519397', '2011-04-07', 1.11, 70),
#  (405, 'USC00519397', '2011-04-08', 0.36, 70),
#  (406, 'USC00519397', '2011-04-09', 0.02, 76),
#  (407, 'USC00519397', '2011-04-10', 0.0, 76),
#  (408, 'USC00519397', '2011-04-11', 0.0, 76),
#  (409, 'USC00519397', '2011-04-12', 0.0, 76),
#  (410, 'USC00519397', '2011-04-13', 0.0, 70),
#  (411, 'USC00519397', '2011-04-15', 0.0, 77),
#  (412, 'USC00519397', '2011-04-16', 0.12, 74),
#  (413, 'USC00519397', '2011-04-17', 0.0, 73),
#  (414, 'USC00519397', '2011-04-18', 0.0, 76),
#  (415, 'USC00519397', '2011-04-19', 0.0, 76),
#  (416, 'USC00519397', '2011-04-20', 0.0, 74),
#  (417, 'USC00519397', '2011-04-21', 0.0, 77),
#  (418, 'USC00519397', '2011-04-22', 0.0, 77),
#  (419, 'USC00519397', '2011-04-23', 0.0, 78),
#  (420, 'USC00519397', '2011-04-24', 0.0, 77),
#  (421, 'USC00519397', '2011-04-25', 0.0, 77),
#  (422, 'USC00519397', '2011-04-26', 0.0, 76),
#  (423, 'USC00519397', '2011-04-27', 0.0, 77),
#  (424, 'USC00519397', '2011-04-29', 0.0, 78),
#  (425, 'USC00519397', '2011-04-30', 0.04, 76),
#  (426, 'USC00519397', '2011-05-01', 0.0, 77),
#  (427, 'USC00519397', '2011-05-02', 0.0, 77),
#  (428, 'USC00519397', '2011-05-03', 2.1, 70),
#  (429, 'USC00519397', '2011-05-04', 0.02, 76),
#  (430, 'USC00519397', '2011-05-05', 0.12, 74),
#  (431, 'USC00519397', '2011-05-06', 0.12, 72),
#  (432, 'USC00519397', '2011-05-07', 0.55, 74),
#  (433, 'USC00519397', '2011-05-08', 0.55, 73),
#  (434, 'USC00519397', '2011-05-09', 0.02, 75),
#  (435, 'USC00519397', '2011-05-10', 0.11, 75),
#  (436, 'USC00519397', '2011-05-11', 0.1, 75),
#  (437, 'USC00519397', '2011-05-12', 0.0, 76),
#  (438, 'USC00519397', '2011-05-13', 0.0, 77),
#  (439, 'USC00519397', '2011-05-14', 0.0, 78),
#  (440, 'USC00519397', '2011-05-15', 0.0, 77),
#  (441, 'USC00519397', '2011-05-16', 0.0, 78),
#  (442, 'USC00519397', '2011-05-17', 0.0, 77),
#  (443, 'USC00519397', '2011-05-18', 0.0, 76),
#  (444, 'USC00519397', '2011-05-19', 0.01, 77),
#  (445, 'USC00519397', '2011-05-20', 0.0, 79),
#  (446, 'USC00519397', '2011-05-21', 0.0, 77),
#  (447, 'USC00519397', '2011-05-22', 0.06, 74),
#  (448, 'USC00519397', '2011-05-23', 0.02, 78),
#  (449, 'USC00519397', '2011-05-24', 0.0, 77),
#  (450, 'USC00519397', '2011-05-25', 0.0, 79),
#  (451, 'USC00519397', '2011-05-26', 0.0, 78),
#  (452, 'USC00519397', '2011-05-27', 0.0, 78),
#  (453, 'USC00519397', '2011-05-28', 0.0, 77),
#  (454, 'USC00519397', '2011-05-29', 0.0, 78),
#  (455, 'USC00519397', '2011-05-30', 0.0, 78),
#  (456, 'USC00519397', '2011-05-31', 0.05, 73),
#  (457, 'USC00519397', '2011-06-01', 0.07, 77),
#  (458, 'USC00519397', '2011-06-02', 0.0, 78),
#  (459, 'USC00519397', '2011-06-03', 0.56, 73),
#  (460, 'USC00519397', '2011-06-04', 0.89, 70),
#  (461, 'USC00519397', '2011-06-05', 0.0, 76),
#  (462, 'USC00519397', '2011-06-06', 0.0, 77),
#  (463, 'USC00519397', '2011-06-07', 0.0, 77),
#  (464, 'USC00519397', '2011-06-08', 0.03, 77),
#  (465, 'USC00519397', '2011-06-09', 0.01, 77),
#  (466, 'USC00519397', '2011-06-10', 0.0, 78),
#  (467, 'USC00519397', '2011-06-11', 0.0, 77),
#  (468, 'USC00519397', '2011-06-12', 0.0, 77),
#  (469, 'USC00519397', '2011-06-13', 0.0, 78),
#  (470, 'USC00519397', '2011-06-14', 0.0, 78),
#  (471, 'USC00519397', '2011-06-15', 0.0, 77),
#  (472, 'USC00519397', '2011-06-17', 0.0, 78),
#  (473, 'USC00519397', '2011-06-18', 0.0, 78),
#  (474, 'USC00519397', '2011-06-19', 0.05, 75),
#  (475, 'USC00519397', '2011-06-20', 0.06, 76),
#  (476, 'USC00519397', '2011-06-21', 0.07, 76),
#  (477, 'USC00519397', '2011-06-25', 0.0, 78),
#  (478, 'USC00519397', '2011-06-26', 0.0, 76),
#  (479, 'USC00519397', '2011-06-27', 0.01, 77),
#  (480, 'USC00519397', '2011-06-28', 0.01, 75),
#  (481, 'USC00519397', '2011-06-29', 0.0, 77),
#  (482, 'USC00519397', '2011-07-01', 0.05, 77),
#  (483, 'USC00519397', '2011-07-02', 0.02, 78),
#  (484, 'USC00519397', '2011-07-03', 0.0, 78),
#  (485, 'USC00519397', '2011-07-04', 0.0, 78),
#  (486, 'USC00519397', '2011-07-05', 0.01, 78),
#  (487, 'USC00519397', '2011-07-06', 0.01, 76),
#  (488, 'USC00519397', '2011-07-07', 0.01, 76),
#  (489, 'USC00519397', '2011-07-08', 0.0, 77),
#  (490, 'USC00519397', '2011-07-09', 0.03, 77),
#  (491, 'USC00519397', '2011-07-10', 0.02, 77),
#  (492, 'USC00519397', '2011-07-11', 0.0, 78),
#  (493, 'USC00519397', '2011-07-12', 0.0, 77),
#  (494, 'USC00519397', '2011-07-13', 0.15, 73),
#  (495, 'USC00519397', '2011-07-14', 0.0, 77),
#  (496, 'USC00519397', '2011-07-15', 0.0, 79),
#  (497, 'USC00519397', '2011-07-16', 0.0, 78),
#  (498, 'USC00519397', '2011-07-17', 0.04, 77),
#  (499, 'USC00519397', '2011-07-18', 0.0, 78),
#  (500, 'USC00519397', '2011-07-19', 0.0, 78),
#  (501, 'USC00519397', '2011-07-20', 0.0, 76),
#  (502, 'USC00519397', '2011-07-21', 0.03, 77),
#  (503, 'USC00519397', '2011-07-23', 0.0, 78),
#  (504, 'USC00519397', '2011-07-24', 0.0, 77),
#  (505, 'USC00519397', '2011-07-25', 0.0, 78),
#  (506, 'USC00519397', '2011-07-26', 0.0, 78),
#  (507, 'USC00519397', '2011-07-27', 0.04, 77),
#  (508, 'USC00519397', '2011-07-28', 0.09, 77),
#  (509, 'USC00519397', '2011-07-29', 0.04, 78),
#  (510, 'USC00519397', '2011-07-30', 0.12, 80),
#  (511, 'USC00519397', '2011-07-31', 0.0, 77),
#  (512, 'USC00519397', '2011-08-01', 0.0, 78),
#  (513, 'USC00519397', '2011-08-02', 0.0, 77),
#  (514, 'USC00519397', '2011-08-03', 0.0, 78),
#  (515, 'USC00519397', '2011-08-04', 0.02, 76),
#  (516, 'USC00519397', '2011-08-05', 0.03, 78),
#  (517, 'USC00519397', '2011-08-06', 0.01, 77),
#  (518, 'USC00519397', '2011-08-07', 0.0, 78),
#  (519, 'USC00519397', '2011-08-08', 0.0, 78),
#  (520, 'USC00519397', '2011-08-09', 0.0, 79),
#  (521, 'USC00519397', '2011-08-11', 0.0, 78),
#  (522, 'USC00519397', '2011-08-12', 0.0, 78),
#  (523, 'USC00519397', '2011-08-13', 0.0, 76),
#  (524, 'USC00519397', '2011-08-14', 0.0, 78),
#  (525, 'USC00519397', '2011-08-15', 0.0, 77),
#  (526, 'USC00519397', '2011-08-16', 0.0, 79),
#  (527, 'USC00519397', '2011-08-17', 0.02, 77),
#  (528, 'USC00519397', '2011-08-18', 0.0, 77),
#  (529, 'USC00519397', '2011-08-19', 0.0, 78),
#  (530, 'USC00519397', '2011-08-20', 0.07, 77),
#  (531, 'USC00519397', '2011-08-21', 0.0, 77),
#  (532, 'USC00519397', '2011-08-22', 0.0, 78),
#  (533, 'USC00519397', '2011-08-23', 0.0, 78),
#  (534, 'USC00519397', '2011-08-24', 0.0, 79),
#  (535, 'USC00519397', '2011-08-25', 0.0, 78),
#  (536, 'USC00519397', '2011-08-26', 0.0, 78),
#  (537, 'USC00519397', '2011-08-27', 0.0, 79),
#  (538, 'USC00519397', '2011-08-28', 0.05, 76),
#  (539, 'USC00519397', '2011-08-29', 0.1, 76),
#  (540, 'USC00519397', '2011-08-30', 0.02, 78),
#  (541, 'USC00519397', '2011-08-31', 0.0, 79),
#  (542, 'USC00519397', '2011-09-02', 0.0, 79),
#  (543, 'USC00519397', '2011-09-03', 0.0, 78),
#  (544, 'USC00519397', '2011-09-04', 0.03, 77),
#  (545, 'USC00519397', '2011-09-05', 0.0, 77),
#  (546, 'USC00519397', '2011-09-06', 0.0, 73),
#  (547, 'USC00519397', '2011-09-07', 0.0, 73),
#  (548, 'USC00519397', '2011-09-08', 0.0, 77),
#  (549, 'USC00519397', '2011-09-09', 0.0, 79),
#  (550, 'USC00519397', '2011-09-10', 0.0, 77),
#  (551, 'USC00519397', '2011-09-11', 0.0, 77),
#  (552, 'USC00519397', '2011-09-12', 0.0, 85),
#  (553, 'USC00519397', '2011-09-13', 0.01, 77),
#  (554, 'USC00519397', '2011-09-14', 0.0, 76),
#  (555, 'USC00519397', '2011-09-15', 0.0, 79),
#  (556, 'USC00519397', '2011-09-16', 0.0, 79),
#  (557, 'USC00519397', '2011-09-17', 0.02, 77),
#  (558, 'USC00519397', '2011-09-18', 0.04, 77),
#  (559, 'USC00519397', '2011-09-19', 0.0, 82),
#  (560, 'USC00519397', '2011-09-20', 0.0, 80),
#  (561, 'USC00519397', '2011-09-21', 0.0, 79),
#  (562, 'USC00519397', '2011-09-22', 0.03, 78),
#  (563, 'USC00519397', '2011-09-23', 0.0, 76),
#  (564, 'USC00519397', '2011-09-24', 0.0, 77),
#  (565, 'USC00519397', '2011-09-25', 0.0, 74),
#  (566, 'USC00519397', '2011-09-26', 0.0, 77),
#  (567, 'USC00519397', '2011-09-27', 0.0, 78),
#  (568, 'USC00519397', '2011-09-28', 0.0, 77),
#  (569, 'USC00519397', '2011-10-01', 0.0, 78),
#  (570, 'USC00519397', '2011-10-02', 0.0, 78),
#  (571, 'USC00519397', '2011-10-03', 0.0, 80),
#  (572, 'USC00519397', '2011-10-06', 0.0, 75),
#  (573, 'USC00519397', '2011-10-07', 0.03, 78),
#  (574, 'USC00519397', '2011-10-08', 0.0, 79),
#  (575, 'USC00519397', '2011-10-09', 0.0, 78),
#  (576, 'USC00519397', '2011-10-10', 0.02, 77),
#  (577, 'USC00519397', '2011-10-11', 0.03, 78),
#  (578, 'USC00519397', '2011-10-12', 0.0, 77),
#  (579, 'USC00519397', '2011-10-13', 0.0, 77),
#  (580, 'USC00519397', '2011-10-14', 0.03, 78),
#  (581, 'USC00519397', '2011-10-15', 0.02, 77),
#  (582, 'USC00519397', '2011-10-16', 0.0, 76),
#  (583, 'USC00519397', '2011-10-17', 0.02, 77),
#  (584, 'USC00519397', '2011-10-18', 0.01, 76),
#  (585, 'USC00519397', '2011-10-19', 0.0, 74),
#  (586, 'USC00519397', '2011-10-20', 0.0, 78),
#  (587, 'USC00519397', '2011-10-21', 0.0, 76),
#  (588, 'USC00519397', '2011-10-22', 0.0, 77),
#  (589, 'USC00519397', '2011-10-23', 0.0, 75),
#  (590, 'USC00519397', '2011-10-24', 0.14, 74),
#  (591, 'USC00519397', '2011-10-25', 1.6, 77),
#  (592, 'USC00519397', '2011-10-26', 0.01, 76),
#  (593, 'USC00519397', '2011-10-27', 0.0, 77),
#  (594, 'USC00519397', '2011-10-28', 0.05, 73),
#  (595, 'USC00519397', '2011-10-29', 0.01, 76),
#  (596, 'USC00519397', '2011-10-30', 0.0, 75),
#  (597, 'USC00519397', '2011-10-31', 0.03, 76),
#  (598, 'USC00519397', '2011-11-01', 0.58, 71),
#  (599, 'USC00519397', '2011-11-02', 0.28, 77),
#  (600, 'USC00519397', '2011-11-03', 0.02, 77),
#  (601, 'USC00519397', '2011-11-04', 0.01, 75),
#  (602, 'USC00519397', '2011-11-05', 0.0, 76),
#  (603, 'USC00519397', '2011-11-06', 0.0, 77),
#  (604, 'USC00519397', '2011-11-07', 0.0, 78),
#  (605, 'USC00519397', '2011-11-08', 0.0, 76),
#  (606, 'USC00519397', '2011-11-09', 0.02, 76),
#  (607, 'USC00519397', '2011-11-10', 0.0, 76),
#  (608, 'USC00519397', '2011-11-11', 0.05, 74),
#  (609, 'USC00519397', '2011-11-12', 0.0, 75),
#  (610, 'USC00519397', '2011-11-13', 0.0, 76),
#  (611, 'USC00519397', '2011-11-14', 0.0, 73),
#  (612, 'USC00519397', '2011-11-15', 0.0, 71),
#  (613, 'USC00519397', '2011-11-16', 0.0, 75),
#  (614, 'USC00519397', '2011-11-17', 0.0, 76),
#  (615, 'USC00519397', '2011-11-18', 0.0, 78),
#  (616, 'USC00519397', '2011-11-19', 0.0, 76),
#  (617, 'USC00519397', '2011-11-20', 0.0, 75),
#  (618, 'USC00519397', '2011-11-21', 0.01, 76),
#  (619, 'USC00519397', '2011-11-22', 0.02, 73),
#  (620, 'USC00519397', '2011-11-23', 0.01, 75),
#  (621, 'USC00519397', '2011-11-24', 0.0, 73),
#  (622, 'USC00519397', '2011-11-25', 0.01, 70),
#  (623, 'USC00519397', '2011-11-26', 0.02, 75),
#  (624, 'USC00519397', '2011-11-27', 0.07, 73),
#  (625, 'USC00519397', '2011-11-28', 0.0, 72),
#  (626, 'USC00519397', '2011-11-29', 0.0, 72),
#  (627, 'USC00519397', '2011-11-30', 0.02, 66),
#  (628, 'USC00519397', '2011-12-01', 0.03, 69),
#  (629, 'USC00519397', '2011-12-02', 0.08, 68),
#  (630, 'USC00519397', '2011-12-03', 0.0, 73),
#  (631, 'USC00519397', '2011-12-04', 0.0, 74),
#  (632, 'USC00519397', '2011-12-05', 0.0, 73),
#  (633, 'USC00519397', '2011-12-06', 0.0, 73),
#  (634, 'USC00519397', '2011-12-07', 0.0, 73),
#  (635, 'USC00519397', '2011-12-08', 0.0, 73),
#  (636, 'USC00519397', '2011-12-09', 0.13, 71),
#  (637, 'USC00519397', '2011-12-10', 0.07, 73),
#  (638, 'USC00519397', '2011-12-11', 0.07, 73),
#  (639, 'USC00519397', '2011-12-12', 0.08, 77),
#  (640, 'USC00519397', '2011-12-13', 0.4, 72),
#  (641, 'USC00519397', '2011-12-14', 0.7, 71),
#  (642, 'USC00519397', '2011-12-15', 0.0, 73),
#  (643, 'USC00519397', '2011-12-16', 0.01, 70),
#  (644, 'USC00519397', '2011-12-17', 0.07, 73),
#  (645, 'USC00519397', '2011-12-18', 0.02, 69),
#  (646, 'USC00519397', '2011-12-19', 0.15, 74),
#  (647, 'USC00519397', '2011-12-20', 0.02, 72),
#  (648, 'USC00519397', '2011-12-21', 0.18, 71),
#  (649, 'USC00519397', '2011-12-22', 0.03, 72),
#  (650, 'USC00519397', '2011-12-23', 0.04, 72),
#  (651, 'USC00519397', '2011-12-24', 0.1, 70),
#  (652, 'USC00519397', '2011-12-25', 0.03, 73),
#  (653, 'USC00519397', '2011-12-26', 0.0, 73),
#  (654, 'USC00519397', '2011-12-27', 0.0, 72),
#  (655, 'USC00519397', '2011-12-28', 0.0, 73),
#  (656, 'USC00519397', '2011-12-29', 0.0, 73),
#  (657, 'USC00519397', '2011-12-30', 0.0, 72),
#  (658, 'USC00519397', '2011-12-31', 0.01, 63),
#  (659, 'USC00519397', '2012-01-01', 0.0, 63),
#  (660, 'USC00519397', '2012-01-02', 0.0, 66),
#  (661, 'USC00519397', '2012-01-03', 0.0, 66),
#  (662, 'USC00519397', '2012-01-04', 0.0, 74),
#  (663, 'USC00519397', '2012-01-06', 0.0, 71),
#  (664, 'USC00519397', '2012-01-07', 0.0, 65),
#  (665, 'USC00519397', '2012-01-08', 0.0, 61),
#  (666, 'USC00519397', '2012-01-10', 0.0, 71),
#  (667, 'USC00519397', '2012-01-11', 0.0, 65),
#  (668, 'USC00519397', '2012-01-12', 0.0, 66),
#  (669, 'USC00519397', '2012-01-14', 0.0, 61),
#  (670, 'USC00519397', '2012-01-15', 0.0, 74),
#  (671, 'USC00519397', '2012-01-16', 0.04, 75),
#  (672, 'USC00519397', '2012-01-17', 0.0, 75),
#  (673, 'USC00519397', '2012-01-18', 0.0, 75),
#  (674, 'USC00519397', '2012-01-19', 0.02, 68),
#  (675, 'USC00519397', '2012-01-20', 0.0, 73),
#  (676, 'USC00519397', '2012-01-21', 0.0, 74),
#  (677, 'USC00519397', '2012-01-22', 0.0, 74),
#  (678, 'USC00519397', '2012-01-23', 0.0, 67),
#  (679, 'USC00519397', '2012-01-24', 0.0, 66),
#  (680, 'USC00519397', '2012-01-25', 0.0, 69),
#  (681, 'USC00519397', '2012-01-26', 0.0, 74),
#  (682, 'USC00519397', '2012-01-27', 0.04, 68),
#  (683, 'USC00519397', '2012-01-28', 0.03, 72),
#  (684, 'USC00519397', '2012-01-29', 1.03, 72),
#  (685, 'USC00519397', '2012-01-30', 0.01, 71),
#  (686, 'USC00519397', '2012-01-31', 0.0, 71),
#  (687, 'USC00519397', '2012-02-01', 0.0, 66),
#  (688, 'USC00519397', '2012-02-02', 0.0, 72),
#  (689, 'USC00519397', '2012-02-03', 0.0, 63),
#  (690, 'USC00519397', '2012-02-04', 0.0, 65),
#  (691, 'USC00519397', '2012-02-05', 0.0, 69),
#  (692, 'USC00519397', '2012-02-06', 0.0, 71),
#  (693, 'USC00519397', '2012-02-07', 0.37, 71),
#  (694, 'USC00519397', '2012-02-08', 0.28, 65),
#  (695, 'USC00519397', '2012-02-09', 0.01, 61),
#  (696, 'USC00519397', '2012-02-10', 0.0, 71),
#  (697, 'USC00519397', '2012-02-11', 0.0, 72),
#  (698, 'USC00519397', '2012-02-12', 0.0, 72),
#  (699, 'USC00519397', '2012-02-13', 0.04, 72),
#  (700, 'USC00519397', '2012-02-14', 0.01, 65),
#  (701, 'USC00519397', '2012-02-15', 0.0, 66),
#  (702, 'USC00519397', '2012-02-16', 0.0, 73),
#  (703, 'USC00519397', '2012-02-17', 0.0, 73),
#  (704, 'USC00519397', '2012-02-18', 0.04, 71),
#  (705, 'USC00519397', '2012-02-19', 0.01, 72),
#  (706, 'USC00519397', '2012-02-20', 0.0, 73),
#  (707, 'USC00519397', '2012-02-21', 0.0, 72),
#  (708, 'USC00519397', '2012-02-22', 0.0, 73),
#  (709, 'USC00519397', '2012-02-23', 0.0, 77),
#  (710, 'USC00519397', '2012-02-24', 0.0, 67),
#  (711, 'USC00519397', '2012-02-25', 0.0, 69),
#  (712, 'USC00519397', '2012-02-26', 0.05, 73),
#  (713, 'USC00519397', '2012-02-27', 0.06, 72),
#  (714, 'USC00519397', '2012-02-28', 0.0, 73),
#  (715, 'USC00519397', '2012-02-29', 0.0, 74),
#  (716, 'USC00519397', '2012-03-01', 0.06, 73),
#  (717, 'USC00519397', '2012-03-02', 0.0, 67),
#  (718, 'USC00519397', '2012-03-03', 0.03, 71),
#  (719, 'USC00519397', '2012-03-04', 0.01, 72),
#  (720, 'USC00519397', '2012-03-05', 1.08, 67),
#  (721, 'USC00519397', '2012-03-06', 4.0, 69),
#  (722, 'USC00519397', '2012-03-07', 2.42, 67),
#  (723, 'USC00519397', '2012-03-08', 0.02, 69),
#  (724, 'USC00519397', '2012-03-09', 0.19, 66),
#  (725, 'USC00519397', '2012-03-10', 0.06, 73),
#  (726, 'USC00519397', '2012-03-11', 0.0, 74),
#  (727, 'USC00519397', '2012-03-12', 0.03, 71),
#  (728, 'USC00519397', '2012-03-13', 0.0, 72),
#  (729, 'USC00519397', '2012-03-14', 0.0, 73),
#  (730, 'USC00519397', '2012-03-15', 0.0, 71),
#  (731, 'USC00519397', '2012-03-16', 0.05, 72),
#  (732, 'USC00519397', '2012-03-17', 0.0, 73),
#  (733, 'USC00519397', '2012-03-18', 0.0, 72),
#  (734, 'USC00519397', '2012-03-19', 0.0, 73),
#  (735, 'USC00519397', '2012-03-20', 0.0, 69),
#  (736, 'USC00519397', '2012-03-21', 0.0, 73),
#  (737, 'USC00519397', '2012-03-22', 0.03, 74),
#  (738, 'USC00519397', '2012-03-23', 0.01, 72),
#  (739, 'USC00519397', '2012-03-24', 0.0, 74),
#  (740, 'USC00519397', '2012-03-25', 0.0, 74),
#  (741, 'USC00519397', '2012-03-26', 0.11, 72),
#  (742, 'USC00519397', '2012-03-27', 0.03, 70),
#  (743, 'USC00519397', '2012-03-28', 0.02, 71),
#  (744, 'USC00519397', '2012-03-29', 0.0, 72),
#  (745, 'USC00519397', '2012-03-30', 0.0, 73),
#  (746, 'USC00519397', '2012-03-31', 0.0, 74),
#  (747, 'USC00519397', '2012-04-01', 0.0, 73),
#  (748, 'USC00519397', '2012-04-02', 0.0, 74),
#  (749, 'USC00519397', '2012-04-03', 0.0, 75),
#  (750, 'USC00519397', '2012-04-04', 0.0, 74),
#  (751, 'USC00519397', '2012-04-05', 0.19, 74),
#  (752, 'USC00519397', '2012-04-06', 0.0, 74),
#  (753, 'USC00519397', '2012-04-07', 0.03, 74),
#  (754, 'USC00519397', '2012-04-08', 0.0, 74),
#  (755, 'USC00519397', '2012-04-09', 0.07, 72),
#  (756, 'USC00519397', '2012-04-10', 0.05, 69),
#  (757, 'USC00519397', '2012-04-11', 0.06, 71),
#  (758, 'USC00519397', '2012-04-12', 0.0, 70),
#  (759, 'USC00519397', '2012-04-13', 0.03, 71),
#  (760, 'USC00519397', '2012-04-14', 0.0, 70),
#  (761, 'USC00519397', '2012-04-15', 0.01, 75),
#  (762, 'USC00519397', '2012-04-16', 0.01, 75),
#  (763, 'USC00519397', '2012-04-17', 0.0, 75),
#  (764, 'USC00519397', '2012-04-18', 0.0, 75),
#  (765, 'USC00519397', '2012-04-19', 0.0, 75),
#  (766, 'USC00519397', '2012-04-20', 0.0, 75),
#  (767, 'USC00519397', '2012-04-21', 0.01, 74),
#  (768, 'USC00519397', '2012-04-22', 0.04, 69),
#  (769, 'USC00519397', '2012-04-23', 0.03, 73),
#  (770, 'USC00519397', '2012-04-24', 0.0, 73),
#  (771, 'USC00519397', '2012-04-25', 0.0, 75),
#  (772, 'USC00519397', '2012-04-26', 0.0, 74),
#  (773, 'USC00519397', '2012-04-27', 0.0, 75),
#  (774, 'USC00519397', '2012-04-28', 0.0, 76),
#  (775, 'USC00519397', '2012-04-29', 0.0, 75),
#  (776, 'USC00519397', '2012-04-30', 0.0, 75),
#  (777, 'USC00519397', '2012-05-01', 0.0, 75),
#  (778, 'USC00519397', '2012-05-02', 0.0, 75),
#  (779, 'USC00519397', '2012-05-03', 0.0, 75),
#  (780, 'USC00519397', '2012-05-04', 0.0, 75),
#  (781, 'USC00519397', '2012-05-05', 0.04, 74),
#  (782, 'USC00519397', '2012-05-06', 0.0, 75),
#  (783, 'USC00519397', '2012-05-07', 0.0, 74),
#  (784, 'USC00519397', '2012-05-08', 0.0, 75),
#  (785, 'USC00519397', '2012-05-09', 0.0, 74),
#  (786, 'USC00519397', '2012-05-10', 0.0, 74),
#  (787, 'USC00519397', '2012-05-11', 0.0, 75),
#  (788, 'USC00519397', '2012-05-12', 0.0, 75),
#  (789, 'USC00519397', '2012-05-13', 0.0, 72),
#  (790, 'USC00519397', '2012-05-14', 0.0, 74),
#  (791, 'USC00519397', '2012-05-15', 0.0, 74),
#  (792, 'USC00519397', '2012-05-16', 0.0, 75),
#  (793, 'USC00519397', '2012-05-17', 0.0, 76),
#  (794, 'USC00519397', '2012-05-18', 0.0, 77),
#  (795, 'USC00519397', '2012-05-19', 0.0, 77),
#  (796, 'USC00519397', '2012-05-20', 0.0, 77),
#  (797, 'USC00519397', '2012-05-21', 0.0, 76),
#  (798, 'USC00519397', '2012-05-22', 0.0, 77),
#  (799, 'USC00519397', '2012-05-23', 0.0, 76),
#  (800, 'USC00519397', '2012-05-24', 0.0, 78),
#  (801, 'USC00519397', '2012-05-25', 0.0, 77),
#  (802, 'USC00519397', '2012-05-26', 0.0, 76),
#  (803, 'USC00519397', '2012-05-27', 0.0, 76),
#  (804, 'USC00519397', '2012-05-28', 0.0, 77),
#  (805, 'USC00519397', '2012-05-29', 0.0, 76),
#  (806, 'USC00519397', '2012-05-30', 0.0, 76),
#  (807, 'USC00519397', '2012-05-31', 0.01, 73),
#  (808, 'USC00519397', '2012-06-01', 0.02, 76),
#  (809, 'USC00519397', '2012-06-02', 0.02, 76),
#  (810, 'USC00519397', '2012-06-03', 0.0, 75),
#  (811, 'USC00519397', '2012-06-04', 0.0, 77),
#  (812, 'USC00519397', '2012-06-05', 0.0, 77),
#  (813, 'USC00519397', '2012-06-06', 0.0, 76),
#  (814, 'USC00519397', '2012-06-07', 0.0, 78),
#  (815, 'USC00519397', '2012-06-10', 0.0, 77),
#  (816, 'USC00519397', '2012-06-11', 0.0, 76),
#  (817, 'USC00519397', '2012-06-12', 0.0, 76),
#  (818, 'USC00519397', '2012-06-13', 0.0, 77),
#  (819, 'USC00519397', '2012-06-14', 0.0, 77),
#  (820, 'USC00519397', '2012-06-15', 0.0, 78),
#  (821, 'USC00519397', '2012-06-16', 0.0, 77),
#  (822, 'USC00519397', '2012-06-17', 0.0, 77),
#  (823, 'USC00519397', '2012-06-18', 0.0, 77),
#  (824, 'USC00519397', '2012-06-19', 0.0, 76),
#  (825, 'USC00519397', '2012-06-20', 0.0, 75),
#  (826, 'USC00519397', '2012-06-21', 0.0, 76),
#  (827, 'USC00519397', '2012-06-22', 0.0, 76),
#  (828, 'USC00519397', '2012-06-23', 0.0, 77),
#  (829, 'USC00519397', '2012-06-24', 0.0, 76),
#  (830, 'USC00519397', '2012-06-25', 0.03, 73),
#  (831, 'USC00519397', '2012-06-26', 0.15, 73),
#  (832, 'USC00519397', '2012-06-27', 0.01, 75),
#  (833, 'USC00519397', '2012-06-28', 0.0, 77),
#  (834, 'USC00519397', '2012-06-29', 0.05, 76),
#  (835, 'USC00519397', '2012-06-30', 0.0, 77),
#  (836, 'USC00519397', '2012-07-01', 0.0, 76),
#  (837, 'USC00519397', '2012-07-02', 0.0, 77),
#  (838, 'USC00519397', '2012-07-03', 0.04, 74),
#  (839, 'USC00519397', '2012-07-04', 0.01, 77),
#  (840, 'USC00519397', '2012-07-05', 0.03, 77),
#  (841, 'USC00519397', '2012-07-06', 0.0, 78),
#  (842, 'USC00519397', '2012-07-07', 0.04, 76),
#  (843, 'USC00519397', '2012-07-08', 0.0, 77),
#  (844, 'USC00519397', '2012-07-10', 0.0, 76),
#  (845, 'USC00519397', '2012-07-11', 0.0, 76),
#  (846, 'USC00519397', '2012-07-12', 0.0, 76),
#  (847, 'USC00519397', '2012-07-13', 0.0, 77),
#  (848, 'USC00519397', '2012-07-14', 0.0, 78),
#  (849, 'USC00519397', '2012-07-15', 0.0, 77),
#  (850, 'USC00519397', '2012-07-16', 0.01, 78),
#  (851, 'USC00519397', '2012-07-17', 0.0, 78),
#  (852, 'USC00519397', '2012-07-18', 0.0, 78),
#  (853, 'USC00519397', '2012-07-19', 0.0, 75),
#  (854, 'USC00519397', '2012-07-20', 0.0, 77),
#  (855, 'USC00519397', '2012-07-21', 0.0, 76),
#  (856, 'USC00519397', '2012-07-22', 0.0, 76),
#  (857, 'USC00519397', '2012-07-23', 0.0, 79),
#  (858, 'USC00519397', '2012-07-24', 0.0, 77),
#  (859, 'USC00519397', '2012-07-25', 0.0, 77),
#  (860, 'USC00519397', '2012-07-26', 0.02, 77),
#  (861, 'USC00519397', '2012-07-27', 0.0, 77),
#  (862, 'USC00519397', '2012-07-28', 0.0, 77),
#  (863, 'USC00519397', '2012-07-29', 0.01, 73),
#  (864, 'USC00519397', '2012-07-30', 0.01, 78),
#  (865, 'USC00519397', '2012-07-31', 0.0, 78),
#  (866, 'USC00519397', '2012-08-01', 0.0, 79),
#  (867, 'USC00519397', '2012-08-02', 0.0, 78),
#  (868, 'USC00519397', '2012-08-03', 0.0, 78),
#  (869, 'USC00519397', '2012-08-04', 0.0, 78),
#  (870, 'USC00519397', '2012-08-05', 0.0, 78),
#  (871, 'USC00519397', '2012-08-06', 0.0, 77),
#  (872, 'USC00519397', '2012-08-07', 0.0, 77),
#  (873, 'USC00519397', '2012-08-08', 0.02, 78),
#  (874, 'USC00519397', '2012-08-09', 0.0, 78),
#  (875, 'USC00519397', '2012-08-10', 0.0, 76),
#  (876, 'USC00519397', '2012-08-11', 0.0, 75),
#  (877, 'USC00519397', '2012-08-12', 0.0, 78),
#  (878, 'USC00519397', '2012-08-13', 0.0, 78),
#  (879, 'USC00519397', '2012-08-14', 0.0, 77),
#  (880, 'USC00519397', '2012-08-15', 0.01, 79),
#  (881, 'USC00519397', '2012-08-16', 0.0, 78),
#  (882, 'USC00519397', '2012-08-17', 0.0, 78),
#  (883, 'USC00519397', '2012-08-20', 0.0, 79),
#  (884, 'USC00519397', '2012-08-21', 0.0, 77),
#  (885, 'USC00519397', '2012-08-22', 0.03, 77),
#  (886, 'USC00519397', '2012-08-23', 0.0, 78),
#  (887, 'USC00519397', '2012-08-24', 0.0, 78),
#  (888, 'USC00519397', '2012-08-25', 0.0, 78),
#  (889, 'USC00519397', '2012-08-26', 0.0, 78),
#  (890, 'USC00519397', '2012-08-27', 0.02, 73),
#  (891, 'USC00519397', '2012-08-28', 1.0, 75),
#  (892, 'USC00519397', '2012-08-29', 0.02, 78),
#  (893, 'USC00519397', '2012-08-30', 0.04, 78),
#  (894, 'USC00519397', '2012-08-31', 0.0, 78),
#  (895, 'USC00519397', '2012-09-01', 0.01, 77),
#  (896, 'USC00519397', '2012-09-02', 0.04, 76),
#  (897, 'USC00519397', '2012-09-03', 0.06, 77),
#  (898, 'USC00519397', '2012-09-04', 0.0, 77),
#  (899, 'USC00519397', '2012-09-05', 0.01, 75),
#  (900, 'USC00519397', '2012-09-06', 0.04, 77),
#  (901, 'USC00519397', '2012-09-07', 0.0, 75),
#  (902, 'USC00519397', '2012-09-08', 0.06, 78),
#  (903, 'USC00519397', '2012-09-09', 0.0, 76),
#  (904, 'USC00519397', '2012-09-10', 0.0, 77),
#  (905, 'USC00519397', '2012-09-11', 0.0, 77),
#  (906, 'USC00519397', '2012-09-12', 0.02, 76),
#  (907, 'USC00519397', '2012-09-13', 0.05, 76),
#  (908, 'USC00519397', '2012-09-14', 0.04, 78),
#  (909, 'USC00519397', '2012-09-15', 0.0, 78),
#  (910, 'USC00519397', '2012-09-16', 0.0, 77),
#  (911, 'USC00519397', '2012-09-17', 0.0, 78),
#  (912, 'USC00519397', '2012-09-18', 0.06, 71),
#  (913, 'USC00519397', '2012-09-19', 0.0, 74),
#  (914, 'USC00519397', '2012-09-20', 0.07, 76),
#  (915, 'USC00519397', '2012-09-21', 0.08, 77),
#  (916, 'USC00519397', '2012-09-22', 0.0, 77),
#  (917, 'USC00519397', '2012-09-23', 0.04, 76),
#  (918, 'USC00519397', '2012-09-24', 0.0, 77),
#  (919, 'USC00519397', '2012-09-25', 0.0, 76),
#  (920, 'USC00519397', '2012-09-26', 0.01, 76),
#  (921, 'USC00519397', '2012-09-27', 0.02, 78),
#  (922, 'USC00519397', '2012-09-28', 0.0, 78),
#  (923, 'USC00519397', '2012-09-29', 0.0, 77),
#  (924, 'USC00519397', '2012-09-30', 0.02, 75),
#  (925, 'USC00519397', '2012-10-01', 0.0, 78),
#  (926, 'USC00519397', '2012-10-02', 0.0, 74),
#  (927, 'USC00519397', '2012-10-03', 0.0, 75),
#  (928, 'USC00519397', '2012-10-04', 0.0, 77),
#  (929, 'USC00519397', '2012-10-05', 0.0, 73),
#  (930, 'USC00519397', '2012-10-06', 0.03, 73),
#  (931, 'USC00519397', '2012-10-07', 0.0, 76),
#  (932, 'USC00519397', '2012-10-08', 0.0, 78),
#  (933, 'USC00519397', '2012-10-09', 0.0, 75),
#  (934, 'USC00519397', '2012-10-10', 0.0, 75),
#  (935, 'USC00519397', '2012-10-11', 0.0, 80),
#  (936, 'USC00519397', '2012-10-12', 0.0, 78),
#  (937, 'USC00519397', '2012-10-13', 0.0, 79),
#  (938, 'USC00519397', '2012-10-14', 0.0, 78),
#  (939, 'USC00519397', '2012-10-15', 0.02, 78),
#  (940, 'USC00519397', '2012-10-16', 0.0, 77),
#  (941, 'USC00519397', '2012-10-17', 0.0, 72),
#  (942, 'USC00519397', '2012-10-18', 0.0, 75),
#  (943, 'USC00519397', '2012-10-19', 0.0, 77),
#  (944, 'USC00519397', '2012-10-20', 0.0, 78),
#  (945, 'USC00519397', '2012-10-21', 0.0, 77),
#  (946, 'USC00519397', '2012-10-22', 0.0, 76),
#  (947, 'USC00519397', '2012-10-23', 0.0, 78),
#  (948, 'USC00519397', '2012-10-24', 0.0, 78),
#  (949, 'USC00519397', '2012-10-25', 0.0, 76),
#  (950, 'USC00519397', '2012-10-26', 0.0, 76),
#  (951, 'USC00519397', '2012-10-27', 0.0, 74),
#  (952, 'USC00519397', '2012-10-28', 0.02, 77),
#  (953, 'USC00519397', '2012-10-29', 0.04, 77),
#  (954, 'USC00519397', '2012-10-30', 0.0, 76),
#  (955, 'USC00519397', '2012-10-31', 0.02, 78),
#  (956, 'USC00519397', '2012-11-01', 0.0, 71),
#  (957, 'USC00519397', '2012-11-02', 0.0, 70),
#  (958, 'USC00519397', '2012-11-03', 0.0, 74),
#  (959, 'USC00519397', '2012-11-04', 0.0, 71),
#  (960, 'USC00519397', '2012-11-05', 0.0, 69),
#  (961, 'USC00519397', '2012-11-06', 0.0, 76),
#  (962, 'USC00519397', '2012-11-07', 0.0, 77),
#  (963, 'USC00519397', '2012-11-08', 0.0, 77),
#  (964, 'USC00519397', '2012-11-09', 0.03, 76),
#  (965, 'USC00519397', '2012-11-10', 0.0, 75),
#  (966, 'USC00519397', '2012-11-11', 0.0, 76),
#  (967, 'USC00519397', '2012-11-12', 0.0, 77),
#  (968, 'USC00519397', '2012-11-13', 0.06, 77),
#  (969, 'USC00519397', '2012-11-14', 0.0, 77),
#  (970, 'USC00519397', '2012-11-15', 0.08, 75),
#  (971, 'USC00519397', '2012-11-16', 0.03, 73),
#  (972, 'USC00519397', '2012-11-17', 0.01, 74),
#  (973, 'USC00519397', '2012-11-18', 0.03, 76),
#  (974, 'USC00519397', '2012-11-19', 0.0, 75),
#  (975, 'USC00519397', '2012-11-20', 0.0, 75),
#  (976, 'USC00519397', '2012-11-21', 0.0, 71),
#  (977, 'USC00519397', '2012-11-22', 0.0, 69),
#  (978, 'USC00519397', '2012-11-23', 0.0, 71),
#  (979, 'USC00519397', '2012-11-24', 0.02, 69),
#  (980, 'USC00519397', '2012-11-25', 0.0, 74),
#  (981, 'USC00519397', '2012-11-26', 0.06, 72),
#  (982, 'USC00519397', '2012-11-27', 0.0, 74),
#  (983, 'USC00519397', '2012-11-28', 0.0, 65),
#  (984, 'USC00519397', '2012-11-29', 0.0, 67),
#  (985, 'USC00519397', '2012-11-30', 0.0, 65),
#  (986, 'USC00519397', '2012-12-01', 0.0, 65),
#  (987, 'USC00519397', '2012-12-02', 0.0, 71),
#  (988, 'USC00519397', '2012-12-03', 0.0, 76),
#  (989, 'USC00519397', '2012-12-04', 0.2, 70),
#  (990, 'USC00519397', '2012-12-05', 0.01, 76),
#  (991, 'USC00519397', '2012-12-08', 0.0, 69),
#  (992, 'USC00519397', '2012-12-09', 0.0, 74),
#  (993, 'USC00519397', '2012-12-10', 0.0, 76),
#  (994, 'USC00519397', '2012-12-11', 0.0, 74),
#  (995, 'USC00519397', '2012-12-12', 0.0, 73),
#  (996, 'USC00519397', '2012-12-13', 0.14, 73),
#  (997, 'USC00519397', '2012-12-14', 0.09, 74),
#  (998, 'USC00519397', '2012-12-15', 0.01, 73),
#  (999, 'USC00519397', '2012-12-16', 0.02, 73),
#  (1000, 'USC00519397', '2012-12-17', 0.02, 73),
#  ...]

# %%
# Use `engine.execute` to select and display the rows from the Measurements table
### BEGIN SOLUTION
engine.execute('SELECT * FROM Stations').fetchall()
### END SOLUTION
# Out:
# [(1, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (2, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (3, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (4, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (5, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (6, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (7, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (8, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (9, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (10, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (11, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (12, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (13, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (14, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (15, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (16, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (17, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (18, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (19, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (20, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (21, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (22, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (23, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (24, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (25, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (26, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (27, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (28, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (29, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (30, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (31, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (32, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (33, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (34, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (35, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (36, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (37, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (38, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (39, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (40, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (41, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (42, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (43, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (44, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (45, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (46, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (47, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (48, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (49, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (50, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (51, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (52, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (53, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (54, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (55, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (56, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (57, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (58, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (59, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (60, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (61, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (62, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (63, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (64, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (65, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (66, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (67, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (68, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (69, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (70, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (71, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (72, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (73, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (74, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (75, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (76, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (77, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (78, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (79, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (80, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (81, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (82, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (83, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (84, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (85, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (86, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (87, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (88, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (89, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (90, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (91, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (92, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (93, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (94, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (95, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (96, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (97, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (98, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (99, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (100, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (101, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (102, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (103, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (104, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (105, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (106, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (107, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (108, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (109, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (110, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (111, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (112, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (113, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (114, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (115, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (116, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (117, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (118, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (119, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (120, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (121, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (122, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (123, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (124, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999998, 32.9),
#  (125, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (126, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4),
#  (127, 'USC00519397', 'WAIKIKI 717.2, HI US', 21.2716, -157.8168, 3.0),
#  (128, 'USC00513117', 'KANEOHE 838.1, HI US', 21.4234, -157.8015, 14.6),
#  (129, 'USC00514830', 'KUALOA RANCH HEADQUARTERS 886.9, HI US', 21.5213, -157.8374, 7.0),
#  (130, 'USC00517948', 'PEARL CITY, HI US', 21.3934, -157.9751, 11.9),
#  (131, 'USC00518838', 'UPPER WAHIAWA 874.3, HI US', 21.4992, -158.0111, 306.6),
#  (132, 'USC00519523', 'WAIMANALO EXPERIMENTAL FARM, HI US', 21.33556, -157.71139, 19.5),
#  (133, 'USC00519281', 'WAIHEE 837.5, HI US', 21.45167, -157.84888999999995, 32.9),
#  (134, 'USC00511918', 'HONOLULU OBSERVATORY 702.2, HI US', 21.3152, -157.9992, 0.9),
#  (135, 'USC00516128', 'MANOA LYON ARBO 785.2, HI US', 21.3331, -157.8025, 152.4)]

# %%
# Reflect Database into ORM class
Base.prepare(engine, reflect=True)
Measurements = Base.classes.Measurements
Stations = Base.classes.Stations

# %%
# Start a session to query the database
session = Session(engine)

# %%
# Query Measurements for 'date' & 'prcp'into results
### BEGIN SOLUTION
results = session.query(Measurements.date, func.avg(Measurements.prcp).label("Average_Percipitation")).filter(Measurements.date.between('2016-08-23', '2017-08-23')).\
    group_by(Measurements.date)
results
### END SOLUTION

# %%
#Load the query results into a Pandas DataFrame and set the index to the date column.
df = pd.read_sql(results.statement, session.bind)
df
# Out:
#            date  Average_Percipitation
# 0    2016-08-23               0.451667
# 1    2016-08-24               1.555000
# 2    2016-08-25               0.077143
# 3    2016-08-26               0.016667
# 4    2016-08-27               0.064000
# 5    2016-08-28               0.516667
# 6    2016-08-29               0.243333
# 7    2016-08-30               0.011667
# 8    2016-08-31               0.636000
# 9    2016-09-01               0.006000
# 10   2016-09-02               0.050000
# 11   2016-09-03               0.254000
# 12   2016-09-04               0.276000
# 13   2016-09-05               0.085000
# 14   2016-09-06               0.246000
# 15   2016-09-07               0.333333
# 16   2016-09-08               0.076667
# 17   2016-09-09               0.178333
# 18   2016-09-10               0.280000
# 19   2016-09-11               0.250000
# 20   2016-09-12               0.308000
# 21   2016-09-13               0.451667
# 22   2016-09-14               2.380000
# 23   2016-09-15               0.826667
# 24   2016-09-16               0.117143
# 25   2016-09-17               0.136000
# 26   2016-09-18               0.106000
# 27   2016-09-19               0.064000
# 28   2016-09-20               0.147143
# 29   2016-09-21               0.195000
# ..          ...                    ...
# 336  2017-07-25               0.087143
# 337  2017-07-26               0.083333
# 338  2017-07-27               0.001667
# 339  2017-07-28               0.110000
# 340  2017-07-29               0.101667
# 341  2017-07-30               0.060000
# 342  2017-07-31               0.000000
# 343  2017-08-01               0.046667
# 344  2017-08-02               0.075000
# 345  2017-08-03               0.017500
# 346  2017-08-04               0.015000
# 347  2017-08-05               0.030000
# 348  2017-08-06               0.000000
# 349  2017-08-07               0.012500
# 350  2017-08-08               0.110000
# 351  2017-08-09               0.050000
# 352  2017-08-10               0.017500
# 353  2017-08-11               0.000000
# 354  2017-08-12               0.046667
# 355  2017-08-13               0.000000
# 356  2017-08-14               0.062000
# 357  2017-08-15               0.164000
# 358  2017-08-16               0.152500
# 359  2017-08-17               0.047500
# 360  2017-08-18               0.020000
# 361  2017-08-19               0.030000
# 362  2017-08-20               0.005000
# 363  2017-08-21               0.193333
# 364  2017-08-22               0.166667
# 365  2017-08-23               0.132500
#
# [366 rows x 2 columns]

# %%
# Unpack the `date` and `average percipitation` from results and save into separate lists
### BEGIN SOLUTION
df["date"]=pd.to_datetime(df["date"])

df.plot(x= "date", y= "Average_Percipitation", figsize=(15,4))
plt.ylabel("Average Percipitation", fontsize = 15)
plt.xlabel("Date", fontsize = 15)
    #plt.xlim('2017-01-01', top15.iloc[0,0])
plt.title("Average Percipitation in 2017", fontsize = 15)
### END SOLUTION

# %%
print(round(df.describe(),2))
# Out:
#        Average_Percipitation
# count                 366.00
# mean                    0.17
# std                     0.30
# min                     0.00
# 25%                     0.01
# 50%                     0.07
# 75%                     0.19
# max                     2.38

# %%
### BEGIN SOLUTION

#Design a query to calculate the total number of stations.
total_stations = session.query(Stations.station).distinct().count()
print(total_stations)

#Design a query to find the most active stations.
#List the stations and observation counts in descending order
active_stations = session.query(Measurements.station,func.count(Measurements.station).label("Frequency")).group_by(Measurements.station)\
.order_by(func.count(Measurements.station).desc())
active_stations = pd.read_sql(active_stations.statement, session.bind)
active_stations
#Which station has the highest number of observations?
active_stations.iloc[0,:]
# Out:
# 9
# station      USC00519281
# Frequency          44352
# Name: 0, dtype: object

# %%
active_stations.iloc[0,0]
# Out:
# 'USC00519281'

# %%
#Design a query to retrieve the last 12 months of temperature observation data (tobs).
tobs_12 = session.query(Measurements.date, Measurements.tobs).filter(Measurements.date.between('2016-08-23', '2017-08-23'), Measurements.station == active_stations.iloc[0,0])
tobs_12

# %%
temp_df = pd.read_sql(tobs_12.statement, session.bind)
temp_df = round(temp_df,2)
temp_df.describe()
# Out:
#               tobs
# count  5632.000000
# mean     73.107955
# std       4.727006
# min      59.000000
# 25%      70.000000
# 50%      74.000000
# 75%      77.000000
# max      83.000000

# %%
#Filter by the station with the highest number of observations.
#Plot the results as a histogram with bins=12.
temp_df.hist("tobs",bins=12, grid=False)
plt.ylabel("Frequency", fontsize = 15)
plt.xlabel("Temperature", fontsize = 15)
plt.title("Last 12 Months Temperature Histogram", fontsize = 15)

# %%
#Write a function called calc_temps that will accept a start date and end date in the format %Y-%m-%d and return the minimum, average, and maximum temperatures for that range of dates.
def calc_temps(start_date, end_date):
    tobs_12 = session.query(Measurements.date, Measurements.tobs).filter(Measurements.date.between(start_date, end_date), Measurements.station == active_stations.iloc[0,0])
    temps_df = pd.read_sql(tobs_12.statement, session.bind)
    avg_temp = temp_df["tobs"].mean()
    max_temp = temp_df["tobs"].max()
    min_temp = temp_df["tobs"].min()
    print("Minimum Temperature: "+str(min_temp),
          "\nMaximum Temperature "+str(max_temp),
          "\nAverage Temperature "+str(round(avg_temp,2)))
    return min_temp, max_temp, avg_temp

# %%
calc_temps("2017-07-31", "2017-08-23")
# Out:
# Minimum Temperature: 59
# Maximum Temperature 83
# Average Temperature 73.11
# (59, 83, 73.10795454545455)

# %%
temp_val = calc_temps("2017-07-31", "2017-08-23")
# Out:
# Minimum Temperature: 59
# Maximum Temperature 83
# Average Temperature 73.11

# %%
plt.bar(0, temp_val[2], width=1, tick_label=['Average_Temp'])
plt.xlim(-1,1)
plt.errorbar(0, temp_val[2], yerr= (temp_val[1]-temp_val[0])/2, color="r")
# Out:
# <Container object of 3 artists>

# %%
from flask import Flask, jsonify
import os
#################################################
# Flask Setup
#################################################
app = Flask(__name__)
#################################################
# Flask Routes
#################################################

@app.route("/")
def welcome():
    """List all available api routes."""
    return ("Available Routes:<br/> \
            /api/v1.0/precipitation<br/> \
            /api/v1.0/tobs<br/> \
            /api/v1.0/stations")

#Query for the dates and temperature observations from the last year.
#Convert the query results to a Dictionary using date as the key and tobs as the value.
#Return the json representation of your dictionary.
#Return a json list of stations from the dataset.
#Return a json list of Temperature Observations (tobs) for the previous year
#Return a json list of the minimum temperature, the average temperature, and the max temperature for a given start or start-end range.
#When given the start only, calculate TMIN, TAVG, and TMAX for all dates greater than and equal to the start date.
#When given the start and the end date, calculate the TMIN, TAVG, and TMAX for dates between the start and end date inclusive.

@app.route("/api/v1.0/precipitation")
def precipitation():
    precipitation_data = []
    results = session.query(Measurements.date, func.avg(Measurements.prcp).label("Average_Percipitation")).filter(Measurements.date.between('2016-08-23', '2017-08-23')).\
    group_by(Measurements.date).all()
    for precipitation in results:
        precipitation_dict = {}
        precipitation_dict[precipitation.date] = precipitation.Average_Percipitation
        precipitation_data.append(precipitation_dict)
    return jsonify(precipitation_data)
@app.route("/api/v1.0/stations")
def stations():
    results = session.query(Stations.station).distinct().all()
    station_data = [record.station for record in results]
    return jsonify(station_data) 
@app.route("/api/v1.0/tobs")
def tobs():
    results = session.query(Measurements.date, func.avg(Measurements.tobs).label("Average_Temperature")).filter(Measurements.date.between('2016-08-23', '2017-08-23')).\
    group_by(Measurements.tobs).all()
    tobs_data = [record.Average_Temperature for record in results]
    return jsonify(tobs_data)

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-fbba213f070b> in <module>()
#      44
#      45 if __name__ == "__main__":
# ---> 46     app.run(debug=True)
#
# /anaconda/lib/python3.6/site-packages/flask/app.py in run(self, host, port, debug, **options)
#     839         options.setdefault('use_debugger', self.debug)
#     840         try:
# --> 841             run_simple(host, port, self, **options)
#     842         finally:
#     843             # reset the first request information if the development server
#
# /anaconda/lib/python3.6/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#     718             s = socket.socket(address_family, socket.SOCK_STREAM)
#     719             s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 720             s.bind((hostname, port))
#     721             if hasattr(s, 'set_inheritable'):
#     722                 s.set_inheritable(True)
#
# OSError: [Errno 48] Address already in use
